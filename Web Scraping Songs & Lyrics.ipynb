# %% [markdown]
# ## Web Scraping Songs & Lyrics

# %%
import pymysql
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time
import re

# %%
# Define an empty dataframe
songs = pd.DataFrame(columns = ['title', 'artist', 'year'])
x = 0
y = 0

# Scrape the Billboard hot 100 yearly chart for 10 years
for i in range(2011, 2021):
    url = "https://www.billboard.com/charts/year-end/{}/hot-100-songs".format(i)
    header = {'User-Agent' : 'Mozilla/5.0'}
    page = requests.get(url, headers = header)
    doc = BeautifulSoup(page.content, 'html.parser')
    div1 = doc.find_all('div', class_ = 'ye-chart-item__title')
    div2 = doc.find_all('div', class_ = 'ye-chart-item__artist')
    for a in div1:
        songs.loc[x, 'title'] = a.text
        x = x + 1
    for b in div2:
        songs.loc[y, 'artist'] = b.text
        songs.loc[y, 'year'] = i
        y = y + 1
    print('Scraping year', i)

songs
# Out:
# Scraping year 2011
# Scraping year 2012
# Scraping year 2013
# Scraping year 2014
# Scraping year 2015
# Scraping year 2016
# Scraping year 2017
# Scraping year 2018
# Scraping year 2019
# Scraping year 2020
#                          title                                         artist  \
# 0      \nRolling In The Deep\n                                  \n\nAdele\n\n
# 1        \nParty Rock Anthem\n  \nLMFAO Featuring Lauren Bennett & GoonRock\n
# 2                 \nFirework\n                             \n\nKaty Perry\n\n
# 3                     \nE.T.\n            \nKaty Perry Featuring Kanye West\n
# 4       \nGive Me Everything\n  \nPitbull Featuring Ne-Yo, Afrojack & Nayer\n
# ..                         ...                                            ...
# 993  \nMore Than My Hometown\n                          \n\nMorgan Wallen\n\n
# 994          \nLovin' On You\n                             \n\nLuke Combs\n\n
# 995               \nSaid Sum\n                           \n\nMoneybagg Yo\n\n
# 996                  \nSlide\n                        \nH.E.R. Featuring YG\n
# 997           \nWalk Em Down\n           \nNLE Choppa Featuring Roddy Ricch\n
#
#      year
# 0    2011
# 1    2011
# 2    2011
# 3    2011
# 4    2011
# ..    ...
# 993  2020
# 994  2020
# 995  2020
# 996  2020
# 997  2020
#
# [998 rows x 3 columns]

# %%
# Strip the line break
songs['title'] = songs['title'].replace('\n','', regex=True)
songs['artist'] = songs['artist'].replace('\n','', regex=True)
songs
# Out:
#                      title                                     artist  year
# 0      Rolling In The Deep                                      Adele  2011
# 1        Party Rock Anthem  LMFAO Featuring Lauren Bennett & GoonRock  2011
# 2                 Firework                                 Katy Perry  2011
# 3                     E.T.            Katy Perry Featuring Kanye West  2011
# 4       Give Me Everything  Pitbull Featuring Ne-Yo, Afrojack & Nayer  2011
# ..                     ...                                        ...   ...
# 993  More Than My Hometown                              Morgan Wallen  2020
# 994          Lovin' On You                                 Luke Combs  2020
# 995               Said Sum                               Moneybagg Yo  2020
# 996                  Slide                        H.E.R. Featuring YG  2020
# 997           Walk Em Down           NLE Choppa Featuring Roddy Ricch  2020
#
# [998 rows x 3 columns]

# %%
# Strip the song title and artists for lyrics searching
songs_strip = songs.copy()
#songs_strip['title'] = songs_strip['title'].replace('&', 'and', regex=True)
#songs_strip['artist'] = songs_strip['artist'].replace('&', 'and', regex=True)
songs_strip['title'] = songs_strip['title'].replace(r'[^A-Za-z0-9 ]+', '', regex=True)
songs_strip['artist'] = songs_strip['artist'].replace(r'[^A-Za-z0-9 ]+', '', regex=True)
songs_strip['artist'] = songs_strip['artist'].replace(' Featuring.+', '', regex=True)
songs_strip['title'] = songs_strip['title'].replace(' ', '-', regex=True)
songs_strip['artist'] = songs_strip['artist'].replace(' ', '-', regex=True)
songs_strip['concat'] = songs_strip['artist'] + '-' + songs_strip['title']
songs_strip
# Out:
#                      title         artist  year  \
# 0      Rolling-In-The-Deep          Adele  2011
# 1        Party-Rock-Anthem          LMFAO  2011
# 2                 Firework     Katy-Perry  2011
# 3                       ET     Katy-Perry  2011
# 4       Give-Me-Everything        Pitbull  2011
# ..                     ...            ...   ...
# 993  More-Than-My-Hometown  Morgan-Wallen  2020
# 994           Lovin-On-You     Luke-Combs  2020
# 995               Said-Sum   Moneybagg-Yo  2020
# 996                  Slide            HER  2020
# 997           Walk-Em-Down     NLE-Choppa  2020
#
#                                   concat
# 0              Adele-Rolling-In-The-Deep
# 1                LMFAO-Party-Rock-Anthem
# 2                    Katy-Perry-Firework
# 3                          Katy-Perry-ET
# 4             Pitbull-Give-Me-Everything
# ..                                   ...
# 993  Morgan-Wallen-More-Than-My-Hometown
# 994              Luke-Combs-Lovin-On-You
# 995                Moneybagg-Yo-Said-Sum
# 996                            HER-Slide
# 997              NLE-Choppa-Walk-Em-Down
#
# [998 rows x 4 columns]

# %%
# Scraping lyrics
c = 0

for index, row in songs_strip.iterrows():
    concat = str(row['concat'])
    try:
        url_lyrics = "https://genius.com/" + concat + "-lyrics"
        page_lyrics = requests.get(url_lyrics, headers = header)
        doc_lyrics = BeautifulSoup(page_lyrics.content, 'html.parser')
        div = doc_lyrics.find('div', class_ = 'lyrics').get_text()
        div = re.sub(r'[\(\[].*?[\)\]]', '', div)
        songs_strip.loc[c, 'lyrics'] = div
    except:
        songs_strip.loc[c, 'lyrics'] = None
    c = c + 1

songs_strip
# Out:
#                      title         artist  year  \
# 0      Rolling-In-The-Deep          Adele  2011
# 1        Party-Rock-Anthem          LMFAO  2011
# 2                 Firework     Katy-Perry  2011
# 3                       ET     Katy-Perry  2011
# 4       Give-Me-Everything        Pitbull  2011
# ..                     ...            ...   ...
# 993  More-Than-My-Hometown  Morgan-Wallen  2020
# 994           Lovin-On-You     Luke-Combs  2020
# 995               Said-Sum   Moneybagg-Yo  2020
# 996                  Slide            HER  2020
# 997           Walk-Em-Down     NLE-Choppa  2020
#
#                                   concat  \
# 0              Adele-Rolling-In-The-Deep
# 1                LMFAO-Party-Rock-Anthem
# 2                    Katy-Perry-Firework
# 3                          Katy-Perry-ET
# 4             Pitbull-Give-Me-Everything
# ..                                   ...
# 993  Morgan-Wallen-More-Than-My-Hometown
# 994              Luke-Combs-Lovin-On-You
# 995                Moneybagg-Yo-Said-Sum
# 996                            HER-Slide
# 997              NLE-Choppa-Walk-Em-Down
#
#                                                 lyrics
# 0    \n\n\nThere's a fire starting in my heart\nRea...
# 1    \n\n\nParty Rock\nYeah\nWoo!\nLet's go!\n\n\nP...
# 2    \n\n\nDo you ever feel like a plastic bag\nDri...
# 3    \n\n\nYou're so hypnotizing\nCould you be the ...
# 4    \n\n\nMe not workin' hard? Yeah right\nPicture...
# ..                                                 ...
# 993  \n\n\nGirl, our mamas are best friends and so ...
# 994  \n\n\nDon't get me wrong\nI like a bobber on t...
# 995  \n\n\n\n\n\nHuh? \nAh, I thought a broke nigga...
# 996  \n\n\nYou always wearin' them glasses\nYou don...
# 997  \n\n\n\nOoh, ooh, no, no\nNLE the Top Shotta\n...
#
# [998 rows x 5 columns]

# %% [markdown]
# # Spotify ID

# %%
import base64
import json

# %%
# updating syntax in dataframe

# titles
songs_strip["title"][10] = 'S-&-M'
songs_strip["title"][17] = 'Perfect'
songs_strip["title"][138] = 'Ni**as-in-Paris'
songs_strip["title"][239] = 'F**kin-Problems'
songs_strip["title"][285] = 'U.O.E.N.O.'
songs_strip["title"][445] = 'I-Dont-F**k-With-You'
songs_strip["title"][459] = '7/11'
songs_strip["title"][547] = 'H.O.L.Y.'
songs_strip["title"][628] = '1-800-273-8255'
songs_strip["title"][649] = 'T-Shirt'
songs_strip["title"][781] = '1-800-273-8255'
songs_strip["title"][825] = 'Ransom'
songs_strip["title"][991] = 'P*$$y-Fairy-OTW'
songs_strip["title"][996] = 'H.E.R.'


# artists
for row in songs_strip.loc[songs_strip["artist"] == "Pnk"].iterrows():
    i = row[0]
    songs_strip["artist"][i] = "Pink"

for row in songs_strip.loc[songs_strip["artist"] == "Keha"].iterrows():
    i = row[0]
    songs_strip["artist"][i] = 'Ke$ha'

for row in songs_strip.loc[songs_strip["artist"] == "FarEast-Movement"].iterrows():
    i = row[0]
    songs_strip["artist"][i] = 'Far-East-Movement'

songs_strip["artist"][80] = 'Brad-Paisley'
songs_strip["artist"][136] = 'Owl-City'

for row in songs_strip.loc[songs_strip["artist"] == "NeYo"].iterrows():
    i = row[0]
    songs_strip["artist"][i] = 'Ne-Yo'

for row in songs_strip.loc[songs_strip["artist"] == "OT-Genasis"].iterrows():
    i = row[0]
    songs_strip["artist"][i] = 'O.T.-Genasis'

songs_strip["artist"][183] = 'Ke$ha'
songs_strip["artist"][184] = 'T-Pain'
songs_strip["artist"][221] = 'will.i.am,-Britney-Spears'
songs_strip["artist"][239] = 'A$AP-Rocky'
songs_strip["artist"][243] = 'Lana-Del-Rey'
songs_strip["artist"][293] = 'will.i.am'
songs_strip["artist"][385] = 'T.I.'
songs_strip["artist"][388] = 'Mike-Will-Made-It'
songs_strip["artist"][448] = 'T-Wayne'
songs_strip["artist"][517] = 'G-Eazy'
songs_strip["artist"][531] = 'Pink'
songs_strip["artist"][624] = 'Kygo'
songs_strip["artist"][638] = 'Machine-Gun-Kelly'
songs_strip["artist"][723] = 'Marshmello'
songs_strip["artist"][727] = 'G-Eazy'
songs_strip["artist"][742] = 'G-Eazy'
songs_strip["artist"][757] = 'Selena-Gomez'
songs_strip["artist"][771] = 'A$AP-Ferg'
songs_strip["artist"][778] = 'Nio-Garcia'
songs_strip["artist"][780] = 'N.E.R.D.'
songs_strip["artist"][799] = 'Post-Malone'
songs_strip["artist"][848] = 'Gucci-Mane'
songs_strip["artist"][855] = 'Ellie-Goulding'
songs_strip["artist"][920] = 'Dan+Shay'
songs_strip["artist"][932] = 'Jawsh-685'
songs_strip["artist"][947] = 'Black-Eyed-Peas'
songs_strip["artist"][951] = 'Juice-WRLD'
songs_strip["artist"][985] = 'Kane-Brown'

# %%
songs_strip.loc[songs_strip["artist"] == "AAP-Ferg"]
# Out:
# Empty DataFrame
# Columns: [title, artist, year, concat, lyrics]
# Index: []

# %%
# Client Credentials Flow

url = 'https://accounts.spotify.com/api/token'
headers = {}
data = {}

# enter your credentials from spotify developer dashboard
client_id = '6f8b3ac1241549f3bed8987b4df9e142'
client_secret = '512f0b3b62984a5d836a7c09ec82052b'

message = f"{client_id}:{client_secret}"
message_bytes = message.encode('ascii')
base64_bytes = base64.b64encode(message_bytes)
base64_message = base64_bytes.decode('ascii')

headers['Authorization'] = f"Basic {base64_message}"
data['grant_type'] = 'client_credentials'

r = requests.post(url, headers = headers, data=data)

print(json.dumps(r.json(), indent = 2))

token = r.json()['access_token']
# Out:
# {
#   "access_token": "BQD8v457onEE2OA1ao4Z00ZsvwuvT40Rs3dNnNovg_eNu8_ZS2meJVkmTRN9tA3hvPVt9gNOv_Z_P5H8SoM",
#   "token_type": "Bearer",
#   "expires_in": 3600
# }

# %%
# Search API

base_url = 'https://api.spotify.com/v1/search'
spotify_id = [] 
headers = { "Authorization": "Bearer " + token }
count = 1
for i in range(0, len(songs_strip)):
    song = re.sub('-', '%20', songs_strip["title"][i])
    artist = re.sub('-', '%20', songs_strip["artist"][i])

    query = f"track:{song}%20artist:{artist}&type=track&limit=1"

    search_url = base_url + "?q=" + query


    #query = "track:Firework%20artist:Katy%20Perry&type=track&limit=1"

    #search_url = base_url + "?q=" + query

    res = requests.get(search_url, headers=headers)

    doc = res.json()

    #print(json.dumps(doc, indent= 4))

    tracks = doc['tracks']

    all_items = tracks['items']
    if all_items == []:
        spotify_id.append("error")
    else:
        first_result = all_items[0]

        track_id = first_result["id"]

        spotify_id.append(track_id)
    print("Scraped spotify_id " + str(count) + "/" + str(len(songs_strip)))
    
    count += 1
# Out:
# Scraped spotify_id 1/998
# Scraped spotify_id 2/998
# Scraped spotify_id 3/998
# Scraped spotify_id 4/998
# Scraped spotify_id 5/998
# Scraped spotify_id 6/998
# Scraped spotify_id 7/998
# Scraped spotify_id 8/998
# Scraped spotify_id 9/998
# Scraped spotify_id 10/998
# Scraped spotify_id 11/998
# Scraped spotify_id 12/998
# Scraped spotify_id 13/998
# Scraped spotify_id 14/998
# Scraped spotify_id 15/998
# Scraped spotify_id 16/998
# Scraped spotify_id 17/998
# Scraped spotify_id 18/998
# Scraped spotify_id 19/998
# Scraped spotify_id 20/998
# Scraped spotify_id 21/998
# Scraped spotify_id 22/998
# Scraped spotify_id 23/998
# Scraped spotify_id 24/998
# Scraped spotify_id 25/998
# Scraped spotify_id 26/998
# Scraped spotify_id 27/998
# Scraped spotify_id 28/998
# Scraped spotify_id 29/998
# Scraped spotify_id 30/998
# Scraped spotify_id 31/998
# Scraped spotify_id 32/998
# Scraped spotify_id 33/998
# Scraped spotify_id 34/998
# Scraped spotify_id 35/998
# Scraped spotify_id 36/998
# Scraped spotify_id 37/998
# Scraped spotify_id 38/998
# Scraped spotify_id 39/998
# Scraped spotify_id 40/998
# Scraped spotify_id 41/998
# Scraped spotify_id 42/998
# Scraped spotify_id 43/998
# Scraped spotify_id 44/998
# Scraped spotify_id 45/998
# Scraped spotify_id 46/998
# Scraped spotify_id 47/998
# Scraped spotify_id 48/998
# Scraped spotify_id 49/998
# Scraped spotify_id 50/998
# Scraped spotify_id 51/998
# Scraped spotify_id 52/998
# Scraped spotify_id 53/998
# Scraped spotify_id 54/998
# Scraped spotify_id 55/998
# Scraped spotify_id 56/998
# Scraped spotify_id 57/998
# Scraped spotify_id 58/998
# Scraped spotify_id 59/998
# Scraped spotify_id 60/998
# Scraped spotify_id 61/998
# Scraped spotify_id 62/998
# Scraped spotify_id 63/998
# Scraped spotify_id 64/998
# Scraped spotify_id 65/998
# Scraped spotify_id 66/998
# Scraped spotify_id 67/998
# Scraped spotify_id 68/998
# Scraped spotify_id 69/998
# Scraped spotify_id 70/998
# Scraped spotify_id 71/998
# Scraped spotify_id 72/998
# Scraped spotify_id 73/998
# Scraped spotify_id 74/998
# Scraped spotify_id 75/998
# Scraped spotify_id 76/998
# Scraped spotify_id 77/998
# Scraped spotify_id 78/998
# Scraped spotify_id 79/998
# Scraped spotify_id 80/998
# Scraped spotify_id 81/998
# Scraped spotify_id 82/998
# Scraped spotify_id 83/998
# Scraped spotify_id 84/998
# Scraped spotify_id 85/998
# Scraped spotify_id 86/998
# Scraped spotify_id 87/998
# Scraped spotify_id 88/998
# Scraped spotify_id 89/998
# Scraped spotify_id 90/998
# Scraped spotify_id 91/998
# Scraped spotify_id 92/998
# Scraped spotify_id 93/998
# Scraped spotify_id 94/998
# Scraped spotify_id 95/998
# Scraped spotify_id 96/998
# Scraped spotify_id 97/998
# Scraped spotify_id 98/998
# Scraped spotify_id 99/998
# Scraped spotify_id 100/998
# Scraped spotify_id 101/998
# Scraped spotify_id 102/998
# Scraped spotify_id 103/998
# Scraped spotify_id 104/998
# Scraped spotify_id 105/998
# Scraped spotify_id 106/998
# Scraped spotify_id 107/998
# Scraped spotify_id 108/998
# Scraped spotify_id 109/998
# Scraped spotify_id 110/998
# Scraped spotify_id 111/998
# Scraped spotify_id 112/998
# Scraped spotify_id 113/998
# Scraped spotify_id 114/998
# Scraped spotify_id 115/998
# Scraped spotify_id 116/998
# Scraped spotify_id 117/998
# Scraped spotify_id 118/998
# Scraped spotify_id 119/998
# Scraped spotify_id 120/998
# Scraped spotify_id 121/998
# Scraped spotify_id 122/998
# Scraped spotify_id 123/998
# Scraped spotify_id 124/998
# Scraped spotify_id 125/998
# Scraped spotify_id 126/998
# Scraped spotify_id 127/998
# Scraped spotify_id 128/998
# Scraped spotify_id 129/998
# Scraped spotify_id 130/998
# Scraped spotify_id 131/998
# Scraped spotify_id 132/998
# Scraped spotify_id 133/998
# Scraped spotify_id 134/998
# Scraped spotify_id 135/998
# Scraped spotify_id 136/998
# Scraped spotify_id 137/998
# Scraped spotify_id 138/998
# Scraped spotify_id 139/998
# Scraped spotify_id 140/998
# Scraped spotify_id 141/998
# Scraped spotify_id 142/998
# Scraped spotify_id 143/998
# Scraped spotify_id 144/998
# Scraped spotify_id 145/998
# Scraped spotify_id 146/998
# Scraped spotify_id 147/998
# Scraped spotify_id 148/998
# Scraped spotify_id 149/998
# Scraped spotify_id 150/998
# Scraped spotify_id 151/998
# Scraped spotify_id 152/998
# Scraped spotify_id 153/998
# Scraped spotify_id 154/998
# Scraped spotify_id 155/998
# Scraped spotify_id 156/998
# Scraped spotify_id 157/998
# Scraped spotify_id 158/998
# Scraped spotify_id 159/998
# Scraped spotify_id 160/998
# Scraped spotify_id 161/998
# Scraped spotify_id 162/998
# Scraped spotify_id 163/998
# Scraped spotify_id 164/998
# Scraped spotify_id 165/998
# Scraped spotify_id 166/998
# Scraped spotify_id 167/998
# Scraped spotify_id 168/998
# Scraped spotify_id 169/998
# Scraped spotify_id 170/998
# Scraped spotify_id 171/998
# Scraped spotify_id 172/998
# Scraped spotify_id 173/998
# Scraped spotify_id 174/998
# Scraped spotify_id 175/998
# Scraped spotify_id 176/998
# Scraped spotify_id 177/998
# Scraped spotify_id 178/998
# Scraped spotify_id 179/998
# Scraped spotify_id 180/998
# Scraped spotify_id 181/998
# Scraped spotify_id 182/998
# Scraped spotify_id 183/998
# Scraped spotify_id 184/998
# Scraped spotify_id 185/998
# Scraped spotify_id 186/998
# Scraped spotify_id 187/998
# Scraped spotify_id 188/998
# Scraped spotify_id 189/998
# Scraped spotify_id 190/998
# Scraped spotify_id 191/998
# Scraped spotify_id 192/998
# Scraped spotify_id 193/998
# Scraped spotify_id 194/998
# Scraped spotify_id 195/998
# Scraped spotify_id 196/998
# Scraped spotify_id 197/998
# Scraped spotify_id 198/998
# Scraped spotify_id 199/998
# Scraped spotify_id 200/998
# Scraped spotify_id 201/998
# Scraped spotify_id 202/998
# Scraped spotify_id 203/998
# Scraped spotify_id 204/998
# Scraped spotify_id 205/998
# Scraped spotify_id 206/998
# Scraped spotify_id 207/998
# Scraped spotify_id 208/998
# Scraped spotify_id 209/998
# Scraped spotify_id 210/998
# Scraped spotify_id 211/998
# Scraped spotify_id 212/998
# Scraped spotify_id 213/998
# Scraped spotify_id 214/998
# Scraped spotify_id 215/998
# Scraped spotify_id 216/998
# Scraped spotify_id 217/998
# Scraped spotify_id 218/998
# Scraped spotify_id 219/998
# Scraped spotify_id 220/998
# Scraped spotify_id 221/998
# Scraped spotify_id 222/998
# Scraped spotify_id 223/998
# Scraped spotify_id 224/998
# Scraped spotify_id 225/998
# Scraped spotify_id 226/998
# Scraped spotify_id 227/998
# Scraped spotify_id 228/998
# Scraped spotify_id 229/998
# Scraped spotify_id 230/998
# Scraped spotify_id 231/998
# Scraped spotify_id 232/998
# Scraped spotify_id 233/998
# Scraped spotify_id 234/998
# Scraped spotify_id 235/998
# Scraped spotify_id 236/998
# Scraped spotify_id 237/998
# Scraped spotify_id 238/998
# Scraped spotify_id 239/998
# Scraped spotify_id 240/998
# Scraped spotify_id 241/998
# Scraped spotify_id 242/998
# Scraped spotify_id 243/998
# Scraped spotify_id 244/998
# Scraped spotify_id 245/998
# Scraped spotify_id 246/998
# Scraped spotify_id 247/998
# Scraped spotify_id 248/998
# Scraped spotify_id 249/998
# Scraped spotify_id 250/998
# Scraped spotify_id 251/998
# Scraped spotify_id 252/998
# Scraped spotify_id 253/998
# Scraped spotify_id 254/998
# Scraped spotify_id 255/998
# Scraped spotify_id 256/998
# Scraped spotify_id 257/998
# Scraped spotify_id 258/998
# Scraped spotify_id 259/998
# Scraped spotify_id 260/998
# Scraped spotify_id 261/998
# Scraped spotify_id 262/998
# Scraped spotify_id 263/998
# Scraped spotify_id 264/998
# Scraped spotify_id 265/998
# Scraped spotify_id 266/998
# Scraped spotify_id 267/998
# Scraped spotify_id 268/998
# Scraped spotify_id 269/998
# Scraped spotify_id 270/998
# Scraped spotify_id 271/998
# Scraped spotify_id 272/998
# Scraped spotify_id 273/998
# Scraped spotify_id 274/998
# Scraped spotify_id 275/998
# Scraped spotify_id 276/998
# Scraped spotify_id 277/998
# Scraped spotify_id 278/998
# Scraped spotify_id 279/998
# Scraped spotify_id 280/998
# Scraped spotify_id 281/998
# Scraped spotify_id 282/998
# Scraped spotify_id 283/998
# Scraped spotify_id 284/998
# Scraped spotify_id 285/998
# Scraped spotify_id 286/998
# Scraped spotify_id 287/998
# Scraped spotify_id 288/998
# Scraped spotify_id 289/998
# Scraped spotify_id 290/998
# Scraped spotify_id 291/998
# Scraped spotify_id 292/998
# Scraped spotify_id 293/998
# Scraped spotify_id 294/998
# Scraped spotify_id 295/998
# Scraped spotify_id 296/998
# Scraped spotify_id 297/998
# Scraped spotify_id 298/998
# Scraped spotify_id 299/998
# Scraped spotify_id 300/998
# Scraped spotify_id 301/998
# Scraped spotify_id 302/998
# Scraped spotify_id 303/998
# Scraped spotify_id 304/998
# Scraped spotify_id 305/998
# Scraped spotify_id 306/998
# Scraped spotify_id 307/998
# Scraped spotify_id 308/998
# Scraped spotify_id 309/998
# Scraped spotify_id 310/998
# Scraped spotify_id 311/998
# Scraped spotify_id 312/998
# Scraped spotify_id 313/998
# Scraped spotify_id 314/998
# Scraped spotify_id 315/998
# Scraped spotify_id 316/998
# Scraped spotify_id 317/998
# Scraped spotify_id 318/998
# Scraped spotify_id 319/998
# Scraped spotify_id 320/998
# Scraped spotify_id 321/998
# Scraped spotify_id 322/998
# Scraped spotify_id 323/998
# Scraped spotify_id 324/998
# Scraped spotify_id 325/998
# Scraped spotify_id 326/998
# Scraped spotify_id 327/998
# Scraped spotify_id 328/998
# Scraped spotify_id 329/998
# Scraped spotify_id 330/998
# Scraped spotify_id 331/998
# Scraped spotify_id 332/998
# Scraped spotify_id 333/998
# Scraped spotify_id 334/998
# Scraped spotify_id 335/998
# Scraped spotify_id 336/998
# Scraped spotify_id 337/998
# Scraped spotify_id 338/998
# Scraped spotify_id 339/998
# Scraped spotify_id 340/998
# Scraped spotify_id 341/998
# Scraped spotify_id 342/998
# Scraped spotify_id 343/998
# Scraped spotify_id 344/998
# Scraped spotify_id 345/998
# Scraped spotify_id 346/998
# Scraped spotify_id 347/998
# Scraped spotify_id 348/998
# Scraped spotify_id 349/998
# Scraped spotify_id 350/998
# Scraped spotify_id 351/998
# Scraped spotify_id 352/998
# Scraped spotify_id 353/998
# Scraped spotify_id 354/998
# Scraped spotify_id 355/998
# Scraped spotify_id 356/998
# Scraped spotify_id 357/998
# Scraped spotify_id 358/998
# Scraped spotify_id 359/998
# Scraped spotify_id 360/998
# Scraped spotify_id 361/998
# Scraped spotify_id 362/998
# Scraped spotify_id 363/998
# Scraped spotify_id 364/998
# Scraped spotify_id 365/998
# Scraped spotify_id 366/998
# Scraped spotify_id 367/998
# Scraped spotify_id 368/998
# Scraped spotify_id 369/998
# Scraped spotify_id 370/998
# Scraped spotify_id 371/998
# Scraped spotify_id 372/998
# Scraped spotify_id 373/998
# Scraped spotify_id 374/998
# Scraped spotify_id 375/998
# Scraped spotify_id 376/998
# Scraped spotify_id 377/998
# Scraped spotify_id 378/998
# Scraped spotify_id 379/998
# Scraped spotify_id 380/998
# Scraped spotify_id 381/998
# Scraped spotify_id 382/998
# Scraped spotify_id 383/998
# Scraped spotify_id 384/998
# Scraped spotify_id 385/998
# Scraped spotify_id 386/998
# Scraped spotify_id 387/998
# Scraped spotify_id 388/998
# Scraped spotify_id 389/998
# Scraped spotify_id 390/998
# Scraped spotify_id 391/998
# Scraped spotify_id 392/998
# Scraped spotify_id 393/998
# Scraped spotify_id 394/998
# Scraped spotify_id 395/998
# Scraped spotify_id 396/998
# Scraped spotify_id 397/998
# Scraped spotify_id 398/998
# Scraped spotify_id 399/998
# Scraped spotify_id 400/998
# Scraped spotify_id 401/998
# Scraped spotify_id 402/998
# Scraped spotify_id 403/998
# Scraped spotify_id 404/998
# Scraped spotify_id 405/998
# Scraped spotify_id 406/998
# Scraped spotify_id 407/998
# Scraped spotify_id 408/998
# Scraped spotify_id 409/998
# Scraped spotify_id 410/998
# Scraped spotify_id 411/998
# Scraped spotify_id 412/998
# Scraped spotify_id 413/998
# Scraped spotify_id 414/998
# Scraped spotify_id 415/998
# Scraped spotify_id 416/998
# Scraped spotify_id 417/998
# Scraped spotify_id 418/998
# Scraped spotify_id 419/998
# Scraped spotify_id 420/998
# Scraped spotify_id 421/998
# Scraped spotify_id 422/998
# Scraped spotify_id 423/998
# Scraped spotify_id 424/998
# Scraped spotify_id 425/998
# Scraped spotify_id 426/998
# Scraped spotify_id 427/998
# Scraped spotify_id 428/998
# Scraped spotify_id 429/998
# Scraped spotify_id 430/998
# Scraped spotify_id 431/998
# Scraped spotify_id 432/998
# Scraped spotify_id 433/998
# Scraped spotify_id 434/998
# Scraped spotify_id 435/998
# Scraped spotify_id 436/998
# Scraped spotify_id 437/998
# Scraped spotify_id 438/998
# Scraped spotify_id 439/998
# Scraped spotify_id 440/998
# Scraped spotify_id 441/998
# Scraped spotify_id 442/998
# Scraped spotify_id 443/998
# Scraped spotify_id 444/998
# Scraped spotify_id 445/998
# Scraped spotify_id 446/998
# Scraped spotify_id 447/998
# Scraped spotify_id 448/998
# Scraped spotify_id 449/998
# Scraped spotify_id 450/998
# Scraped spotify_id 451/998
# Scraped spotify_id 452/998
# Scraped spotify_id 453/998
# Scraped spotify_id 454/998
# Scraped spotify_id 455/998
# Scraped spotify_id 456/998
# Scraped spotify_id 457/998
# Scraped spotify_id 458/998
# Scraped spotify_id 459/998
# Scraped spotify_id 460/998
# Scraped spotify_id 461/998
# Scraped spotify_id 462/998
# Scraped spotify_id 463/998
# Scraped spotify_id 464/998
# Scraped spotify_id 465/998
# Scraped spotify_id 466/998
# Scraped spotify_id 467/998
# Scraped spotify_id 468/998
# Scraped spotify_id 469/998
# Scraped spotify_id 470/998
# Scraped spotify_id 471/998
# Scraped spotify_id 472/998
# Scraped spotify_id 473/998
# Scraped spotify_id 474/998
# Scraped spotify_id 475/998
# Scraped spotify_id 476/998
# Scraped spotify_id 477/998
# Scraped spotify_id 478/998
# Scraped spotify_id 479/998
# Scraped spotify_id 480/998
# Scraped spotify_id 481/998
# Scraped spotify_id 482/998
# Scraped spotify_id 483/998
# Scraped spotify_id 484/998
# Scraped spotify_id 485/998
# Scraped spotify_id 486/998
# Scraped spotify_id 487/998
# Scraped spotify_id 488/998
# Scraped spotify_id 489/998
# Scraped spotify_id 490/998
# Scraped spotify_id 491/998
# Scraped spotify_id 492/998
# Scraped spotify_id 493/998
# Scraped spotify_id 494/998
# Scraped spotify_id 495/998
# Scraped spotify_id 496/998
# Scraped spotify_id 497/998
# Scraped spotify_id 498/998
# Scraped spotify_id 499/998
# Scraped spotify_id 500/998
# Scraped spotify_id 501/998
# Scraped spotify_id 502/998
# Scraped spotify_id 503/998
# Scraped spotify_id 504/998
# Scraped spotify_id 505/998
# Scraped spotify_id 506/998
# Scraped spotify_id 507/998
# Scraped spotify_id 508/998
# Scraped spotify_id 509/998
# Scraped spotify_id 510/998
# Scraped spotify_id 511/998
# Scraped spotify_id 512/998
# Scraped spotify_id 513/998
# Scraped spotify_id 514/998
# Scraped spotify_id 515/998
# Scraped spotify_id 516/998
# Scraped spotify_id 517/998
# Scraped spotify_id 518/998
# Scraped spotify_id 519/998
# Scraped spotify_id 520/998
# Scraped spotify_id 521/998
# Scraped spotify_id 522/998
# Scraped spotify_id 523/998
# Scraped spotify_id 524/998
# Scraped spotify_id 525/998
# Scraped spotify_id 526/998
# Scraped spotify_id 527/998
# Scraped spotify_id 528/998
# Scraped spotify_id 529/998
# Scraped spotify_id 530/998
# Scraped spotify_id 531/998
# Scraped spotify_id 532/998
# Scraped spotify_id 533/998
# Scraped spotify_id 534/998
# Scraped spotify_id 535/998
# Scraped spotify_id 536/998
# Scraped spotify_id 537/998
# Scraped spotify_id 538/998
# Scraped spotify_id 539/998
# Scraped spotify_id 540/998
# Scraped spotify_id 541/998
# Scraped spotify_id 542/998
# Scraped spotify_id 543/998
# Scraped spotify_id 544/998
# Scraped spotify_id 545/998
# Scraped spotify_id 546/998
# Scraped spotify_id 547/998
# Scraped spotify_id 548/998
# Scraped spotify_id 549/998
# Scraped spotify_id 550/998
# Scraped spotify_id 551/998
# Scraped spotify_id 552/998
# Scraped spotify_id 553/998
# Scraped spotify_id 554/998
# Scraped spotify_id 555/998
# Scraped spotify_id 556/998
# Scraped spotify_id 557/998
# Scraped spotify_id 558/998
# Scraped spotify_id 559/998
# Scraped spotify_id 560/998
# Scraped spotify_id 561/998
# Scraped spotify_id 562/998
# Scraped spotify_id 563/998
# Scraped spotify_id 564/998
# Scraped spotify_id 565/998
# Scraped spotify_id 566/998
# Scraped spotify_id 567/998
# Scraped spotify_id 568/998
# Scraped spotify_id 569/998
# Scraped spotify_id 570/998
# Scraped spotify_id 571/998
# Scraped spotify_id 572/998
# Scraped spotify_id 573/998
# Scraped spotify_id 574/998
# Scraped spotify_id 575/998
# Scraped spotify_id 576/998
# Scraped spotify_id 577/998
# Scraped spotify_id 578/998
# Scraped spotify_id 579/998
# Scraped spotify_id 580/998
# Scraped spotify_id 581/998
# Scraped spotify_id 582/998
# Scraped spotify_id 583/998
# Scraped spotify_id 584/998
# Scraped spotify_id 585/998
# Scraped spotify_id 586/998
# Scraped spotify_id 587/998
# Scraped spotify_id 588/998
# Scraped spotify_id 589/998
# Scraped spotify_id 590/998
# Scraped spotify_id 591/998
# Scraped spotify_id 592/998
# Scraped spotify_id 593/998
# Scraped spotify_id 594/998
# Scraped spotify_id 595/998
# Scraped spotify_id 596/998
# Scraped spotify_id 597/998
# Scraped spotify_id 598/998
# Scraped spotify_id 599/998
# Scraped spotify_id 600/998
# Scraped spotify_id 601/998
# Scraped spotify_id 602/998
# Scraped spotify_id 603/998
# Scraped spotify_id 604/998
# Scraped spotify_id 605/998
# Scraped spotify_id 606/998
# Scraped spotify_id 607/998
# Scraped spotify_id 608/998
# Scraped spotify_id 609/998
# Scraped spotify_id 610/998
# Scraped spotify_id 611/998
# Scraped spotify_id 612/998
# Scraped spotify_id 613/998
# Scraped spotify_id 614/998
# Scraped spotify_id 615/998
# Scraped spotify_id 616/998
# Scraped spotify_id 617/998
# Scraped spotify_id 618/998
# Scraped spotify_id 619/998
# Scraped spotify_id 620/998
# Scraped spotify_id 621/998
# Scraped spotify_id 622/998
# Scraped spotify_id 623/998
# Scraped spotify_id 624/998
# Scraped spotify_id 625/998
# Scraped spotify_id 626/998
# Scraped spotify_id 627/998
# Scraped spotify_id 628/998
# Scraped spotify_id 629/998
# Scraped spotify_id 630/998
# Scraped spotify_id 631/998
# Scraped spotify_id 632/998
# Scraped spotify_id 633/998
# Scraped spotify_id 634/998
# Scraped spotify_id 635/998
# Scraped spotify_id 636/998
# Scraped spotify_id 637/998
# Scraped spotify_id 638/998
# Scraped spotify_id 639/998
# Scraped spotify_id 640/998
# Scraped spotify_id 641/998
# Scraped spotify_id 642/998
# Scraped spotify_id 643/998
# Scraped spotify_id 644/998
# Scraped spotify_id 645/998
# Scraped spotify_id 646/998
# Scraped spotify_id 647/998
# Scraped spotify_id 648/998
# Scraped spotify_id 649/998
# Scraped spotify_id 650/998
# Scraped spotify_id 651/998
# Scraped spotify_id 652/998
# Scraped spotify_id 653/998
# Scraped spotify_id 654/998
# Scraped spotify_id 655/998
# Scraped spotify_id 656/998
# Scraped spotify_id 657/998
# Scraped spotify_id 658/998
# Scraped spotify_id 659/998
# Scraped spotify_id 660/998
# Scraped spotify_id 661/998
# Scraped spotify_id 662/998
# Scraped spotify_id 663/998
# Scraped spotify_id 664/998
# Scraped spotify_id 665/998
# Scraped spotify_id 666/998
# Scraped spotify_id 667/998
# Scraped spotify_id 668/998
# Scraped spotify_id 669/998
# Scraped spotify_id 670/998
# Scraped spotify_id 671/998
# Scraped spotify_id 672/998
# Scraped spotify_id 673/998
# Scraped spotify_id 674/998
# Scraped spotify_id 675/998
# Scraped spotify_id 676/998
# Scraped spotify_id 677/998
# Scraped spotify_id 678/998
# Scraped spotify_id 679/998
# Scraped spotify_id 680/998
# Scraped spotify_id 681/998
# Scraped spotify_id 682/998
# Scraped spotify_id 683/998
# Scraped spotify_id 684/998
# Scraped spotify_id 685/998
# Scraped spotify_id 686/998
# Scraped spotify_id 687/998
# Scraped spotify_id 688/998
# Scraped spotify_id 689/998
# Scraped spotify_id 690/998
# Scraped spotify_id 691/998
# Scraped spotify_id 692/998
# Scraped spotify_id 693/998
# Scraped spotify_id 694/998
# Scraped spotify_id 695/998
# Scraped spotify_id 696/998
# Scraped spotify_id 697/998
# Scraped spotify_id 698/998
# Scraped spotify_id 699/998
# Scraped spotify_id 700/998
# Scraped spotify_id 701/998
# Scraped spotify_id 702/998
# Scraped spotify_id 703/998
# Scraped spotify_id 704/998
# Scraped spotify_id 705/998
# Scraped spotify_id 706/998
# Scraped spotify_id 707/998
# Scraped spotify_id 708/998
# Scraped spotify_id 709/998
# Scraped spotify_id 710/998
# Scraped spotify_id 711/998
# Scraped spotify_id 712/998
# Scraped spotify_id 713/998
# Scraped spotify_id 714/998
# Scraped spotify_id 715/998
# Scraped spotify_id 716/998
# Scraped spotify_id 717/998
# Scraped spotify_id 718/998
# Scraped spotify_id 719/998
# Scraped spotify_id 720/998
# Scraped spotify_id 721/998
# Scraped spotify_id 722/998
# Scraped spotify_id 723/998
# Scraped spotify_id 724/998
# Scraped spotify_id 725/998
# Scraped spotify_id 726/998
# Scraped spotify_id 727/998
# Scraped spotify_id 728/998
# Scraped spotify_id 729/998
# Scraped spotify_id 730/998
# Scraped spotify_id 731/998
# Scraped spotify_id 732/998
# Scraped spotify_id 733/998
# Scraped spotify_id 734/998
# Scraped spotify_id 735/998
# Scraped spotify_id 736/998
# Scraped spotify_id 737/998
# Scraped spotify_id 738/998
# Scraped spotify_id 739/998
# Scraped spotify_id 740/998
# Scraped spotify_id 741/998
# Scraped spotify_id 742/998
# Scraped spotify_id 743/998
# Scraped spotify_id 744/998
# Scraped spotify_id 745/998
# Scraped spotify_id 746/998
# Scraped spotify_id 747/998
# Scraped spotify_id 748/998
# Scraped spotify_id 749/998
# Scraped spotify_id 750/998
# Scraped spotify_id 751/998
# Scraped spotify_id 752/998
# Scraped spotify_id 753/998
# Scraped spotify_id 754/998
# Scraped spotify_id 755/998
# Scraped spotify_id 756/998
# Scraped spotify_id 757/998
# Scraped spotify_id 758/998
# Scraped spotify_id 759/998
# Scraped spotify_id 760/998
# Scraped spotify_id 761/998
# Scraped spotify_id 762/998
# Scraped spotify_id 763/998
# Scraped spotify_id 764/998
# Scraped spotify_id 765/998
# Scraped spotify_id 766/998
# Scraped spotify_id 767/998
# Scraped spotify_id 768/998
# Scraped spotify_id 769/998
# Scraped spotify_id 770/998
# Scraped spotify_id 771/998
# Scraped spotify_id 772/998
# Scraped spotify_id 773/998
# Scraped spotify_id 774/998
# Scraped spotify_id 775/998
# Scraped spotify_id 776/998
# Scraped spotify_id 777/998
# Scraped spotify_id 778/998
# Scraped spotify_id 779/998
# Scraped spotify_id 780/998
# Scraped spotify_id 781/998
# Scraped spotify_id 782/998
# Scraped spotify_id 783/998
# Scraped spotify_id 784/998
# Scraped spotify_id 785/998
# Scraped spotify_id 786/998
# Scraped spotify_id 787/998
# Scraped spotify_id 788/998
# Scraped spotify_id 789/998
# Scraped spotify_id 790/998
# Scraped spotify_id 791/998
# Scraped spotify_id 792/998
# Scraped spotify_id 793/998
# Scraped spotify_id 794/998
# Scraped spotify_id 795/998
# Scraped spotify_id 796/998
# Scraped spotify_id 797/998
# Scraped spotify_id 798/998
# Scraped spotify_id 799/998
# Scraped spotify_id 800/998
# Scraped spotify_id 801/998
# Scraped spotify_id 802/998
# Scraped spotify_id 803/998
# Scraped spotify_id 804/998
# Scraped spotify_id 805/998
# Scraped spotify_id 806/998
# Scraped spotify_id 807/998
# Scraped spotify_id 808/998
# Scraped spotify_id 809/998
# Scraped spotify_id 810/998
# Scraped spotify_id 811/998
# Scraped spotify_id 812/998
# Scraped spotify_id 813/998
# Scraped spotify_id 814/998
# Scraped spotify_id 815/998
# Scraped spotify_id 816/998
# Scraped spotify_id 817/998
# Scraped spotify_id 818/998
# Scraped spotify_id 819/998
# Scraped spotify_id 820/998
# Scraped spotify_id 821/998
# Scraped spotify_id 822/998
# Scraped spotify_id 823/998
# Scraped spotify_id 824/998
# Scraped spotify_id 825/998
# Scraped spotify_id 826/998
# Scraped spotify_id 827/998
# Scraped spotify_id 828/998
# Scraped spotify_id 829/998
# Scraped spotify_id 830/998
# Scraped spotify_id 831/998
# Scraped spotify_id 832/998
# Scraped spotify_id 833/998
# Scraped spotify_id 834/998
# Scraped spotify_id 835/998
# Scraped spotify_id 836/998
# Scraped spotify_id 837/998
# Scraped spotify_id 838/998
# Scraped spotify_id 839/998
# Scraped spotify_id 840/998
# Scraped spotify_id 841/998
# Scraped spotify_id 842/998
# Scraped spotify_id 843/998
# Scraped spotify_id 844/998
# Scraped spotify_id 845/998
# Scraped spotify_id 846/998
# Scraped spotify_id 847/998
# Scraped spotify_id 848/998
# Scraped spotify_id 849/998
# Scraped spotify_id 850/998
# Scraped spotify_id 851/998
# Scraped spotify_id 852/998
# Scraped spotify_id 853/998
# Scraped spotify_id 854/998
# Scraped spotify_id 855/998
# Scraped spotify_id 856/998
# Scraped spotify_id 857/998
# Scraped spotify_id 858/998
# Scraped spotify_id 859/998
# Scraped spotify_id 860/998
# Scraped spotify_id 861/998
# Scraped spotify_id 862/998
# Scraped spotify_id 863/998
# Scraped spotify_id 864/998
# Scraped spotify_id 865/998
# Scraped spotify_id 866/998
# Scraped spotify_id 867/998
# Scraped spotify_id 868/998
# Scraped spotify_id 869/998
# Scraped spotify_id 870/998
# Scraped spotify_id 871/998
# Scraped spotify_id 872/998
# Scraped spotify_id 873/998
# Scraped spotify_id 874/998
# Scraped spotify_id 875/998
# Scraped spotify_id 876/998
# Scraped spotify_id 877/998
# Scraped spotify_id 878/998
# Scraped spotify_id 879/998
# Scraped spotify_id 880/998
# Scraped spotify_id 881/998
# Scraped spotify_id 882/998
# Scraped spotify_id 883/998
# Scraped spotify_id 884/998
# Scraped spotify_id 885/998
# Scraped spotify_id 886/998
# Scraped spotify_id 887/998
# Scraped spotify_id 888/998
# Scraped spotify_id 889/998
# Scraped spotify_id 890/998
# Scraped spotify_id 891/998
# Scraped spotify_id 892/998
# Scraped spotify_id 893/998
# Scraped spotify_id 894/998
# Scraped spotify_id 895/998
# Scraped spotify_id 896/998
# Scraped spotify_id 897/998
# Scraped spotify_id 898/998
# Scraped spotify_id 899/998
# Scraped spotify_id 900/998
# Scraped spotify_id 901/998
# Scraped spotify_id 902/998
# Scraped spotify_id 903/998
# Scraped spotify_id 904/998
# Scraped spotify_id 905/998
# Scraped spotify_id 906/998
# Scraped spotify_id 907/998
# Scraped spotify_id 908/998
# Scraped spotify_id 909/998
# Scraped spotify_id 910/998
# Scraped spotify_id 911/998
# Scraped spotify_id 912/998
# Scraped spotify_id 913/998
# Scraped spotify_id 914/998
# Scraped spotify_id 915/998
# Scraped spotify_id 916/998
# Scraped spotify_id 917/998
# Scraped spotify_id 918/998
# Scraped spotify_id 919/998
# Scraped spotify_id 920/998
# Scraped spotify_id 921/998
# Scraped spotify_id 922/998
# Scraped spotify_id 923/998
# Scraped spotify_id 924/998
# Scraped spotify_id 925/998
# Scraped spotify_id 926/998
# Scraped spotify_id 927/998
# Scraped spotify_id 928/998
# Scraped spotify_id 929/998
# Scraped spotify_id 930/998
# Scraped spotify_id 931/998
# Scraped spotify_id 932/998
# Scraped spotify_id 933/998
# Scraped spotify_id 934/998
# Scraped spotify_id 935/998
# Scraped spotify_id 936/998
# Scraped spotify_id 937/998
# Scraped spotify_id 938/998
# Scraped spotify_id 939/998
# Scraped spotify_id 940/998
# Scraped spotify_id 941/998
# Scraped spotify_id 942/998
# Scraped spotify_id 943/998
# Scraped spotify_id 944/998
# Scraped spotify_id 945/998
# Scraped spotify_id 946/998
# Scraped spotify_id 947/998
# Scraped spotify_id 948/998
# Scraped spotify_id 949/998
# Scraped spotify_id 950/998
# Scraped spotify_id 951/998
# Scraped spotify_id 952/998
# Scraped spotify_id 953/998
# Scraped spotify_id 954/998
# Scraped spotify_id 955/998
# Scraped spotify_id 956/998
# Scraped spotify_id 957/998
# Scraped spotify_id 958/998
# Scraped spotify_id 959/998
# Scraped spotify_id 960/998
# Scraped spotify_id 961/998
# Scraped spotify_id 962/998
# Scraped spotify_id 963/998
# Scraped spotify_id 964/998
# Scraped spotify_id 965/998
# Scraped spotify_id 966/998
# Scraped spotify_id 967/998
# Scraped spotify_id 968/998
# Scraped spotify_id 969/998
# Scraped spotify_id 970/998
# Scraped spotify_id 971/998
# Scraped spotify_id 972/998
# Scraped spotify_id 973/998
# Scraped spotify_id 974/998
# Scraped spotify_id 975/998
# Scraped spotify_id 976/998
# Scraped spotify_id 977/998
# Scraped spotify_id 978/998
# Scraped spotify_id 979/998
# Scraped spotify_id 980/998
# Scraped spotify_id 981/998
# Scraped spotify_id 982/998
# Scraped spotify_id 983/998
# Scraped spotify_id 984/998
# Scraped spotify_id 985/998
# Scraped spotify_id 986/998
# Scraped spotify_id 987/998
# Scraped spotify_id 988/998
# Scraped spotify_id 989/998
# Scraped spotify_id 990/998
# Scraped spotify_id 991/998
# Scraped spotify_id 992/998
# Scraped spotify_id 993/998
# Scraped spotify_id 994/998
# Scraped spotify_id 995/998
# Scraped spotify_id 996/998
# Scraped spotify_id 997/998
# Scraped spotify_id 998/998

# %%
# can then look up index of error to see what the problem/typo is
spotify_id.count("error")
# Out:
# 7

# %%
# verify spotify id by searching for the song
# url = 'https://open.spotify.com/track/4cSSL3YafYjM3yjgFO1vJg' + spotify_id

# %%
songs_strip["spotify_id"] = spotify_id

# %% [markdown]
# # Audio Features

# %%
# Getting audio features
import pprint
af_url_base = 'https://api.spotify.com/v1/audio-features/'
audio_features = []
count_af = 1
for i in spotify_id:
    af_url = af_url_base + i
    headers = { "Authorization": "Bearer " + token,
              "Accept": "application/json",
              "Content-Type": "application/json"}
    try:
        af_req = requests.get(af_url, headers=headers)
        af_req.raise_for_status()
        afdoc = af_req.json()
        audio_features.append(afdoc)
    except requests.exceptions.RequestException as e:
        audio_features.append("Null")
        print(e)
    print("Getting Audio Features for id " + str(count_af) + "/" + str(len(songs_strip)))
    count_af += 1
# Out:
# Getting Audio Features for id 1/998
# Getting Audio Features for id 2/998
# Getting Audio Features for id 3/998
# Getting Audio Features for id 4/998
# Getting Audio Features for id 5/998
# Getting Audio Features for id 6/998
# Getting Audio Features for id 7/998
# Getting Audio Features for id 8/998
# Getting Audio Features for id 9/998
# Getting Audio Features for id 10/998
# Getting Audio Features for id 11/998
# Getting Audio Features for id 962/998
# Getting Audio Features for id 963/998
# Getting Audio Features for id 964/998
# Getting Audio Features for id 965/998
# Getting Audio Features for id 966/998
# Getting Audio Features for id 967/998
# Getting Audio Features for id 968/998
# Getting Audio Features for id 969/998
# Getting Audio Features for id 970/998
# Getting Audio Features for id 971/998
# Getting Audio Features for id 972/998
# Getting Audio Features for id 973/998
# Getting Audio Features for id 974/998
# Getting Audio Features for id 975/998
# Getting Audio Features for id 976/998
# Getting Audio Features for id 977/998
# Getting Audio Features for id 978/998
# Getting Audio Features for id 979/998
# Getting Audio Features for id 980/998
# Getting Audio Features for id 981/998
# Getting Audio Features for id 982/998
# Getting Audio Features for id 983/998
# Getting Audio Features for id 984/998
# Getting Audio Features for id 985/998
# Getting Audio Features for id 986/998
# Getting Audio Features for id 987/998
# Getting Audio Features for id 988/998
# Getting Audio Features for id 989/998
# Getting Audio Features for id 990/998
# Getting Audio Features for id 991/998
# Getting Audio Features for id 992/998
# Getting Audio Features for id 993/998
# Getting Audio Features for id 994/998
# Getting Audio Features for id 995/998
# Getting Audio Features for id 996/998
# Getting Audio Features for id 997/998
# Getting Audio Features for id 998/998

# %%
# Seperating features
danceability = []
energy = []
key = []
loudness = []
mode = []
speechiness = []
acousticness = []
instrumentalness = []
liveness = []
valence = []
tempo = []
Type = []
uri = []
track_href = []
duration_ms = []
time_signature = []

# %%
for i in audio_features:
    if i != 'Null':
        danceability.append(i['danceability'])
        energy.append(i['energy'])
        key.append(i['key'])
        loudness.append(i['loudness'])
        mode.append(i['mode'])
        speechiness.append(i['speechiness'])
        acousticness.append(i['acousticness'])
        instrumentalness.append(i['instrumentalness'])
        liveness.append(i['liveness'])
        valence.append(i['valence'])
        tempo.append(i['tempo'])
        Type.append(i['type'])
        uri.append(i['uri'])
        track_href.append(i['track_href'])
        duration_ms.append(i['duration_ms'])
        time_signature.append(i['time_signature'])
    else:
        danceability.append('Null')
        energy.append('Null')
        key.append('Null')
        loudness.append('Null')
        mode.append('Null')
        speechiness.append('Null')
        acousticness.append('Null')
        instrumentalness.append('Null')
        liveness.append('Null')
        valence.append('Null')
        tempo.append('Null')
        Type.append('Null')
        uri.append('Null')
        track_href.append('Null')
        duration_ms.append('Null')
        time_signature.append('Null')

# %%
songs_strip["danceability"] = danceability
songs_strip["energy"] = energy
songs_strip["key"] = key
songs_strip["loudness"] = loudness
songs_strip["mode"] = mode
songs_strip["speechiness"] = speechiness
songs_strip["acousticness"] = acousticness
songs_strip["instrumentalness"] = instrumentalness
songs_strip["liveness"] = liveness
songs_strip["valence"] = valence
songs_strip["tempo"] = tempo
songs_strip["Type"] = Type
songs_strip["uri"] = uri
songs_strip["track_href"] = track_href
songs_strip["duration_ms"] = duration_ms
songs_strip["time_signature"] = time_signature
songs_strip
# Out:
#                      title         artist  year  \
# 0      Rolling-In-The-Deep          Adele  2011
# 1        Party-Rock-Anthem          LMFAO  2011
# 2                 Firework     Katy-Perry  2011
# 3                       ET     Katy-Perry  2011
# 4       Give-Me-Everything        Pitbull  2011
# ..                     ...            ...   ...
# 993  More-Than-My-Hometown  Morgan-Wallen  2020
# 994           Lovin-On-You     Luke-Combs  2020
# 995               Said-Sum   Moneybagg-Yo  2020
# 996                 H.E.R.            HER  2020
# 997           Walk-Em-Down     NLE-Choppa  2020
#
#                                   concat  \
# 0              Adele-Rolling-In-The-Deep
# 1                LMFAO-Party-Rock-Anthem
# 2                    Katy-Perry-Firework
# 3                          Katy-Perry-ET
# 4             Pitbull-Give-Me-Everything
# ..                                   ...
# 993  Morgan-Wallen-More-Than-My-Hometown
# 994              Luke-Combs-Lovin-On-You
# 995                Moneybagg-Yo-Said-Sum
# 996                            HER-Slide
# 997              NLE-Choppa-Walk-Em-Down
#
#                                                 lyrics  \
# 0    \n\n\nThere's a fire starting in my heart\nRea...
# 1    \n\n\nParty Rock\nYeah\nWoo!\nLet's go!\n\n\nP...
# 2    \n\n\nDo you ever feel like a plastic bag\nDri...
# 3    \n\n\nYou're so hypnotizing\nCould you be the ...
# 4    \n\n\nMe not workin' hard? Yeah right\nPicture...
# ..                                                 ...
# 993  \n\n\nGirl, our mamas are best friends and so ...
# 994  \n\n\nDon't get me wrong\nI like a bobber on t...
# 995  \n\n\n\n\n\nHuh? \nAh, I thought a broke nigga...
# 996  \n\n\nYou always wearin' them glasses\nYou don...
# 997  \n\n\n\nOoh, ooh, no, no\nNLE the Top Shotta\n...
#
#                  spotify_id danceability energy key loudness  ...  \
# 0    1c8gk2PeTE04A1pIDH9YMk         0.73  0.769   8   -5.114  ...
# 1    0IkKz2J93C94Ei4BvDop7P         0.75  0.727   5    -4.21  ...
# 2    4lCv7b86sLynZbXhfScfm2        0.638  0.826   8   -4.968  ...
# 3    5v0OGuLQbc3kLWS7fHklzU         0.53  0.902   5   -6.105  ...
# 4    4QNpBfC0zvjKqPJcyqBy9W        0.671  0.939   8   -3.206  ...
# ..                      ...          ...    ...  ..      ...  ...
# 993  5OELUCYgOHKFAvCERnAvfS         0.62  0.869   6   -5.479  ...
# 994  0nYvjcSlCgjcwogQAwIwNp        0.572  0.949   4   -4.865  ...
# 995  3sKz6Sd72K0ofPWcJPPk6H        0.929  0.667   8   -6.789  ...
# 996  0KeE5dKNErVA9ZWx2VfjOC        0.627  0.502  11  -12.351  ...
# 997  4cSSL3YafYjM3yjgFO1vJg        0.867  0.744   2   -5.171  ...
#
#     acousticness instrumentalness liveness valence    tempo            Type  \
# 0          0.138                0   0.0473   0.507  104.948  audio_features
# 1         0.0189                0    0.266   0.359  129.993  audio_features
# 2          0.139                0   0.0803   0.649  124.072  audio_features
# 3        0.00595            0.102    0.139   0.602  150.015  audio_features
# 4          0.191                0    0.298    0.53  129.024  audio_features
# ..           ...              ...      ...     ...      ...             ...
# 993        0.615                0    0.131   0.597  126.019  audio_features
# 994      0.00165         0.000195    0.163    0.53  118.974  audio_features
# 995       0.0185                0      0.1   0.274  126.998  audio_features
# 996        0.181                0    0.129   0.356  110.255  audio_features
# 997        0.268                0   0.0713   0.645   84.005  audio_features
#
#                                       uri  \
# 0    spotify:track:1c8gk2PeTE04A1pIDH9YMk
# 1    spotify:track:0IkKz2J93C94Ei4BvDop7P
# 2    spotify:track:4lCv7b86sLynZbXhfScfm2
# 3    spotify:track:5v0OGuLQbc3kLWS7fHklzU
# 4    spotify:track:4QNpBfC0zvjKqPJcyqBy9W
# ..                                    ...
# 993  spotify:track:5OELUCYgOHKFAvCERnAvfS
# 994  spotify:track:0nYvjcSlCgjcwogQAwIwNp
# 995  spotify:track:3sKz6Sd72K0ofPWcJPPk6H
# 996  spotify:track:0KeE5dKNErVA9ZWx2VfjOC
# 997  spotify:track:4cSSL3YafYjM3yjgFO1vJg
#
#                                             track_href duration_ms  \
# 0    https://api.spotify.com/v1/tracks/1c8gk2PeTE04...      228093
# 1    https://api.spotify.com/v1/tracks/0IkKz2J93C94...      262173
# 2    https://api.spotify.com/v1/tracks/4lCv7b86sLyn...      227880
# 3    https://api.spotify.com/v1/tracks/5v0OGuLQbc3k...      589734
# 4    https://api.spotify.com/v1/tracks/4QNpBfC0zvjK...      252307
# ..                                                 ...         ...
# 993  https://api.spotify.com/v1/tracks/5OELUCYgOHKF...      216573
# 994  https://api.spotify.com/v1/tracks/0nYvjcSlCgjc...      194867
# 995  https://api.spotify.com/v1/tracks/3sKz6Sd72K0o...      155168
# 996  https://api.spotify.com/v1/tracks/0KeE5dKNErVA...      176790
# 997  https://api.spotify.com/v1/tracks/4cSSL3YafYjM...      173288
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 993              4
# 994              4
# 995              4
# 996              4
# 997              4
#
# [998 rows x 22 columns]

# %% [markdown]
# ## Database

# %%
# Create MySQL database
SQL_DB = "hits"
SQL_TABLE = "hits_lyrics"
SQL_TABLE_DEF = "(" + \
            "id INT NOT NULL AUTO_INCREMENT PRIMARY KEY" + \
            ",title VARCHAR(100)" + \
            ",artist VARCHAR(100)" + \
            ",year YEAR(4)" + \
            ",year TEXT" + \
            ")"
conn = mysql.connector.connect(host='localhost', user='root')
cursor = conn.cursor()
query1 = "CREATE DATABASE IF NOT EXISTS " + SQL_DB
print(query1)
cursor.execute(query1);
        
query2 = "CREATE TABLE IF NOT EXISTS " + SQL_DB + "." + SQL_TABLE + " " + SQL_TABLE_DEF + ";";
print(query2)
cursor.execute(query2);
cursor.close()
conn.close()

# %% [markdown]
# # Back up codes

# %%
# In case we have to fix the songs with errors:

#for idx, i in  enumerate(audio_features):
    if i == "Null":
        af_url = af_url_base + i
        headers = { "Authorization": "Bearer " + token,
                  "Accept": "application/json",
                  "Content-Type": "application/json"}
        try:
            af_req = requests.get(af_url, headers=headers)
            af_req.raise_for_status()
            afdoc = af_req.json()
            audio_features[index] = afdoc
        except requests.exceptions.RequestException as e:
            audio_features[index] = "Null"
            print(e)
# check if still null:

pprint.pprint(audio_features[92])
# Out:
# 400 Client Error: Bad Request for url: https://api.spotify.com/v1/audio-features/Null
# 400 Client Error: Bad Request for url: https://api.spotify.com/v1/audio-features/Null
# 400 Client Error: Bad Request for url: https://api.spotify.com/v1/audio-features/Null
# 400 Client Error: Bad Request for url: https://api.spotify.com/v1/audio-features/Null
# 400 Client Error: Bad Request for url: https://api.spotify.com/v1/audio-features/Null
# 400 Client Error: Bad Request for url: https://api.spotify.com/v1/audio-features/Null
# 400 Client Error: Bad Request for url: https://api.spotify.com/v1/audio-features/Null
# 400 Client Error: Bad Request for url: https://api.spotify.com/v1/audio-features/Null
# 400 Client Error: Bad Request for url: https://api.spotify.com/v1/audio-features/Null
# 400 Client Error: Bad Request for url: https://api.spotify.com/v1/audio-features/Null
# 400 Client Error: Bad Request for url: https://api.spotify.com/v1/audio-features/Null
# 400 Client Error: Bad Request for url: https://api.spotify.com/v1/audio-features/Null
# 'Null'

# %%
# Counting how many nulls
nnn = 0
for i in audio_features:
    if i == "Null":
        nnn += 1
nnn
# Out:
# 13
